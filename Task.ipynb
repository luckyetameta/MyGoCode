# %% [markdown]
# <a href="https://colab.research.google.com/github/luckyetameta/MyGoCode/blob/main/Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rang = range(2000, 3201)
lis = []
for num in rang:
  if num % 7 == 0 and num % 5 !=0:
    lis.append(num)
    print(lis)
# Out:
# [2002]
# [2002, 2009]
# [2002, 2009, 2016]
# [2002, 2009, 2016, 2023]
# [2002, 2009, 2016, 2023, 2037]
# [2002, 2009, 2016, 2023, 2037, 2044]
# [2002, 2009, 2016, 2023, 2037, 2044, 2051]
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058]
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072]
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079]
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086]
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093]
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093, 2107]
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093, 2107, 2114]
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093, 2107, 2114, 2121]
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093, 2107, 2114, 2121, 2128]
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093, 2107, 2114, 2121, 2128, 2142]
# ...

# %%
lis2 = [x for x in range(2000, 3201) if x % 7 == 0 and x% 5 != 0]
print(lis2)
# Out:
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093, 2107, 2114, 2121, 2128, 2142, 2149, 2156, 2163, 2177, 2184, 2191, 2198, 2212, 2219, 2226, 2233, 2247, 2254, 2261, 2268, 2282, 2289, 2296, 2303, 2317, 2324, 2331, 2338, 2352, 2359, 2366, 2373, 2387, 2394, 2401, 2408, 2422, 2429, 2436, 2443, 2457, 2464, 2471, 2478, 2492, 2499, 2506, 2513, 2527, 2534, 2541, 2548, 2562, 2569, 2576, 2583, 2597, 2604, 2611, 2618, 2632, 2639, 2646, 2653, 2667, 2674, 2681, 2688, 2702, 2709, 2716, 2723, 2737, 2744, 2751, 2758, 2772, 2779, 2786, 2793, 2807, 2814, 2821, 2828, 2842, 2849, 2856, 2863, 2877, 2884, 2891, 2898, 2912, 2919, 2926, 2933, 2947, 2954, 2961, 2968, 2982, 2989, 2996, 3003, 3017, 3024, 3031, 3038, 3052, 3059, 3066, 3073, 3087, 3094, 3101, 3108, 3122, 3129, 3136, 3143, 3157, 3164, 3171, 3178, 3192, 3199]

# %%
#this is the rerursive function
def factorial(x):
  if x > 1:
    return (x * factorial(x-1))
  elif x == 1:

    # recursive call to the function 

    return 1
  else:
    return 0



# change the value for a different result
num =7

result = factorial(num)

print("the factorial of", num, "is", result)
# Out:
# the factorial of 7 is 5040

# %%
# Out:
# the factorial of 7 is 5040

# %%
import math
math.factorial(6)
# Out:
# 720

# %%
dic ={}
def sqr(a,b):
  for i in range(a, b):
    dic.update({i: i*i})
  print(dic)

# %%
sqr(1,7)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36}

# %%
sqr(1, 20)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225, 16: 256, 17: 289, 18: 324, 19: 361}

# %%
dic=sqr(1, 7)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36}
